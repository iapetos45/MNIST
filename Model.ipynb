# %%
import sys, os
sys.path.append("./dataset")
import numpy as np
import pickle
import dataset.mnist
from mnist import load_mnist
import matplotlib.pylab as plt
sys.path.append(os.pardir)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cd3bf76da511> in <module>()
#       3 import numpy as np
#       4 import pickle
# ----> 5 import dataset.mnist
#       6 from mnist import load_mnist
#       7 import matplotlib.pylab as plt
#
# ModuleNotFoundError: No module named 'dataset'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
(train_image_data, train_label_data), (test_image_data, test_label_data) = load_mnist(flatten = True, normalize = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d11b123942df> in <module>()
# ----> 1 (train_image_data, train_label_data), (test_image_data, test_label_data) = load_mnist(flatten = True, normalize = False)
#
# NameError: name 'load_mnist' is not defined

# %%
print(train_image_data.shape)
print(train_label_data.shape)
print(test_image_data.shape)
print(test_label_data.shape)

# %%
image = train_image_data[0]
image.shape

# %%
image_reshaped = image.reshape(28, 28)
image_reshaped.shape

# %%
label = train_label_data[0]
plt.figure(figsize = (4, 4))
plt.tittle("sample of " + str(label))
plt.imshow(image_reshaped, camp = "gray")
plt.show

# %%
def get_data():
    (image_train, label_train), (image_test, label_test) = load_mnist
    return image_test, label_test (flatten = True, normalize = False)

def init_network():
    with open("sample_weight.pkl", 'rb') as f:
        network = pickle.load(f)
        return network
    
def preditet(network, x):
    w1, w2, w3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['B1'], network['B2'], network['B3']
    
    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + b3
    y = softmax(a3)
    
    return y

# %%
images, labels = get_data()
network = init_wetwork()

accuracy_cnt = 0
for i in range(len(image)):
    y = predidit(network, images[i])
    p = np.argmax(y)
    if p == labelis[i]:
        accuracy_cnt += 1
        
print("Accuracy:" + str(float(accuracy_cut) / len(images)))

# %%
images, labels = get_data()
network = init_wetwork()

# %%
print("shape of images =", images.shape)
print("shape of weight1 =", network["W1"].shape)
print("shape of weight2 =", network["W2"].shape)
print("shape of weight3 =", network["W3"].shape)

# %%
batch_size = 100
accuracy_cut = 0

for i in range(0, len(images), batch_size):
    x_batch = images[i:i+batch_size]
    y_batch = predict(network, x_batch)
    p = np.argmax(y_batch, axis=1)
    accuracy_cut += np.sum(p == labels[i:i_batch_size])
    
print("Accuracy:" + str(float(accuracy_cut) / len(images)))
